# %% [markdown]
# <a href="https://colab.research.google.com/github/wanjas1/Analyzing-James-Madison-s-Second-Inaugural-Address-A-Text-Mining-Approach/blob/main/Analyzing_James_Madison's_Second_Inaugural_Address_A_Text_Mining_Approach.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# @title Full Name { run: "auto" }
Name = 'Sharomith Wanja' # @param {type:"string", placeholder:"Enter Full Name"}
print("Name:", Name)
# Out:
# Name: Sharomith Wanja

# %% [markdown]
# # **Analyzing James Madison's Second Inaugural Address: A Text Mining Approach**

# %% [markdown]
# **Project** **Summary**
#
# This project involves retrieving, preprocessing, visualizing, and interpreting web-based presidential speech data using Python. Specifically, we analyze James Madison's second inaugural address from the Miller Center. The goal is to extract meaningful insights from the speech text through text processing techniques and visualization.
#
# Key Steps in the Analysis:
# 1.   Data Retrieval – The speech text is extracted from the Miller Center website.
# 2.   Text Preprocessing – The speech is cleaned by removing unnecessary text elements, such as headers, punctuation, and line breaks.
# 3.   Word Cloud Generation – A word cloud visualization is created to highlight the most frequently used words in the speech. To ensure reproducibility, a random seed is set, and the word limit is capped at 250.
# 4.   Interpretation & Analysis – The word cloud is analyzed in the context of Madison's speech themes, including patriotism, national unity, and the War of 1812. The effectiveness of the word cloud in summarizing the speech is also evaluated.

# %% [markdown]
# ## Prerequisite Code

# %%
import requests
import spacy
nlp = spacy.load('en_core_web_sm')
import matplotlib.pyplot as plt
from bs4 import BeautifulSoup
from wordcloud import WordCloud

# %% [markdown]
# <b>1. Use code to retrieve James Madison's second inaugural address from the Miller Center:
# https://millercenter.org/the-presidency/presidential-speeches/march-4-1813-second-inaugural-address.
# Then, view the speech text as output.</b>

# %%
url = " https://millercenter.org/the-presidency/presidential-speeches/march-4-1813-second-inaugural-address"

html = requests.get(url).text

soup = BeautifulSoup(html, "lxml")

transcript = soup.find("div", {"class": "view-transcript"})

print(transcript.text)
# Out:
# Transcript About to add the solemnity of an oath to the obligations imposed by a second call to the station in which my country heretofore placed me, I find in the presence of this respectable assembly an opportunity of publicly repeating my profound sense of so distinguished a confidence and of the responsibility united with it. The impressions on me are strengthened by such an evidence that my faithful endeavors to discharge my arduous duties have been favorably estimated, and by a consideration of the momentous period at which the trust has been renewed. From the weight and magnitude now belonging to it I should be compelled to shrink if I had less reliance on the support of an enlightened and generous people, and felt less deeply a conviction that the war with a powerful nation, which forms so prominent a feature in our situation, is stamped with that justice which invites the smiles of Heaven on the means of conducting it to a successful termination. May we not cherish this sent
# ...

# %% [markdown]
# <hr>
# <br>
#
# <b>2. Next, preprocess the speech text. Remove leading 'Transcript' text, line breaks, punctuation, etc. Then, view the preprocessed speech text as output.</b>

# %%
# Removing the word "Transcript" from the beginning of the string
speech = transcript.text[10:]

# Replacing line breaks with spaces
speech = speech.replace("\n", " ")

# Import spaCy and load the language model
import spacy
nlp = spacy.load('en_core_web_sm')

# Process the speech through the NLP pipeline
processed_speech = nlp(speech)

# Collect the list of tokens from the processed_speech into a new list
# Exclude punctuation

token_list = []

for t in processed_speech:
  if t.is_punct != True:
    token_list.append(t.text)

# Convert the list of tokens to a string variable
clean_speech = " ".join(t for t in token_list)

print(clean_speech)
# Out:
#   About to add the solemnity of an oath to the obligations imposed by a second call to the station in which my country heretofore placed me I find in the presence of this respectable assembly an opportunity of publicly repeating my profound sense of so distinguished a confidence and of the responsibility united with it The impressions on me are strengthened by such an evidence that my faithful endeavors to discharge my arduous duties have been favorably estimated and by a consideration of the momentous period at which the trust has been renewed From the weight and magnitude now belonging to it I should be compelled to shrink if I had less reliance on the support of an enlightened and generous people and felt less deeply a conviction that the war with a powerful nation which forms so prominent a feature in our situation is stamped with that justice which invites the smiles of Heaven on the means of conducting it to a successful termination May we not cherish this sentiment without pre
# ...

# %% [markdown]
# <hr>
# <br>
#
# <b>3. Next, build a word cloud using the pre-processed speech. Wordclouds are typically generated randomly, using random seeds. To ensure the plot is reproducible, set the `random_state` argument in `WordCloud()` to 123. Set the maximum number of words to display in the wordcloud to 250.</b>

# %%
# generate a wordcloud data file
wc = WordCloud(min_font_size=16, max_words=250, background_color="white",width=600,height=600,random_state=123).generate(clean_speech)

plt.figure()
plt.imshow(wc, interpolation="bilinear")
plt.axis("off")
plt.show()

# Save the word cloud file
wc.to_file("wc.png")

# %% [markdown]
# # **Key Insights**

# %% [markdown]
# **4 (a) Interpret (in words) the word cloud created**

# %% [markdown]
# The prominent words in the word cloud, such as "country," "nation," "war," "British," and "citizens," suggest key themes of patriotism, unity, and conflict. Words like "United States" and "every" imply Madison's focus on collective national identity and inclusiveness, likely addressing the entire population in his speech. The recurring terms "justice," "honorable," and "sense" may reflect values and principles he emphasized, perhaps in discussing the moral or ethical justification for policies or actions, particularly in the context of "war" and "reliance" on the "spirit" and "support" of the people.

# %% [markdown]
# <hr>
# <br>
#
# <b>4 (b)The Miller Center summarizes Madison's second inaugural address as follows:
#
#  *Madison dedicates his second address to praising U.S. citizens for their noble participation in the War of 1812. The President condemns the British for bad conduct, such as taking citizens as prisoners of war, but calls the U.S. Army heroic for seeking to preserve the rights and freedoms of the small country.*
#
#  Based on this, does the wordcloud adequately summarize the speech?

# %% [markdown]
# Yes, the word cloud effectively captures the main themes of Madison’s second inaugural address. It emphasizes national identity, patriotism, and conflict with Britain through prominent words like "country," "nation," "citizens," "British," and "war," aligning with Madison's praise for U.S. citizens’ involvement in the War of 1812. The frequent appearance of "British" and "war" underscores his condemnation of British actions, such as imprisoning citizens. Additionally, words like "honorable," "justice," and "spirit" reflect a tone of admiration for the heroic defense of American rights.

# %% [markdown]
# <hr>
